# %%
f=open('all_candidates.txt','r')
c=0
sample=[]
sarray=[]

s1=['HC1-11225-P-HC', 'HC1-11225-P-HC', 'HC1-11225-P-HC', 'HC1-11225-P-HC']
for line in f:
    c=c+1
    if c<1048577:
        #print (line)
        eachLine=line.strip().split('\t')
        #print (len(eachLine))
        #print(eachLine[1])
        s=eachLine[0]
        #print (s)
        if c==1:
            sample.append(s)
            #s='HC1-11226-P-HC'
        #print(s,type(s))
        if c==1048576:
            print (s)
        if s  not in sample:
            if c>1:
                sample.append(s)
                print ("i am different")
#f.close()
print (sample)
# Out:
# i am different
# i am different
# HC1-11227-P-HC
# ['HC1-11225-P-HC', 'HC1-11226-P-HC', 'HC1-11227-P-HC']

# %%
f=open('all_candidates.txt','r')
c=0
sample=[]
flag=0
list=[]
#s1=['HC1-11225-P-HC', 'HC1-11225-P-HC', 'HC1-11225-P-HC', 'HC1-11225-P-HC']
for line in f:
    c=c+1
    if c<20:
        print (line)
        eachLine=line.strip().split('\t')
        #print (len(eachLine))
        #print(eachLine[1])
        s=eachLine[0]
        #print (s)
        if c==1:
            sample.append(s)
            #s='HC1-11226-P-HC'
        #print(s,type(s))
        if c==20:
            print (s)
        if s  not in sample:
            
            if c>1:
                sample.append(s)
                print ("i am different")
#f.close()
print (sample)
# Out:
# HC1-11225-P-HC	chr1:23343	CA	0.89	transcript	WASH7P
#
# HC1-11225-P-HC	chr1:23359	CG	0.10	transcript	WASH7P
#
# HC1-11225-P-HC	chr1:27843	AG	1.00	transcript	WASH7P
#
# HC1-11225-P-HC	chr1:27876	TA	1.00	transcript	WASH7P
#
# HC1-11225-P-HC	chr1:87409	CT	1.00	-	-
#
# HC1-11225-P-HC	chr1:90946	TC	0.23	-	-
#
# HC1-11225-P-HC	chr1:91009	TC	0.25	-	-
#
# HC1-11225-P-HC	chr1:91013	TC	0.25	-	-
#
# HC1-11225-P-HC	chr1:91035	TC	0.75	-	-
#
# HC1-11225-P-HC	chr1:91054	TC	0.75	-	-
#
# HC1-11225-P-HC	chr1:91063	TC	1.00	-	-
#
# HC1-11225-P-HC	chr1:91190	GA	1.00	-	-
#
# HC1-11225-P-HC	chr1:99389	CT	0.40	-	-
#
# HC1-11225-P-HC	chr1:103210	GT	0.75	-	-
#
# HC1-11225-P-HC	chr1:103233	CT	0.75	-	-
#
# HC1-11225-P-HC	chr1:103250	GA	0.40	-	-
#
# HC1-11225-P-HC	chr1:108517	TC	0.27	-	-
#
# HC1-11225-P-HC	chr1:108540	AC	0.38	-	-
#
# HC1-11225-P-HC	chr1:121344	GA	0.60	-	-
#
# ['HC1-11225-P-HC']

# %%
f=open('all_candidates.txt','r')
c=0
sample=[]
twod_list = []                                                          
for line in f: 
    c=c+1
    eachLine=line.strip().split('\t')
    #print (eachLine)
    s=eachLine[0]
    if c==1:
            sample.append(s)
            twod_list.append(s)
    
    if s  not in sample:
            
            if c>1:
                sample.append(s)
                print ("i am different")
    new=[]
    
    if c<5:
        c1=eachLine[1]
        s=eachLine[0]
        val=eachLine[3]
        new.append(c1)
        #new.append(s)
        new.append(val)

        #print(new)
        twod_list.append(new)
        
print(twod_list)
# Out:
# i am different
# i am different
# i am different
# i am different
# i am different
# i am different
# i am different
# i am different
# i am different
# ['HC1-11225-P-HC', ['chr1:23343', '0.89'], ['chr1:23359', '0.10'], ['chr1:27843', '1.00'], ['chr1:27876', '1.00']]

# %%
f=open('all_candidates.txt','r')
c=0
sample=[]
sarray=[]

s1=['HC1-11225-P-HC', 'HC1-11225-P-HC', 'HC1-11225-P-HC', 'HC1-11225-P-HC']
for line in f:
    c=c+1
    if c<20:
        #print (line)
        eachLine=line.strip().split('\t')
        #print (len(eachLine))
        #print(eachLine[1])
        s=eachLine[0]
        c1=eachLine[1]
        val=eachLine[3]
        #print (s)
        if c==1:
            sample.append(s)
            
            #s='HC1-11226-P-HC'
        #print(s,type(s))
        #if c==775531:
        if c==20:
            print (s)
        sarray.append(c1)
        sarray.append(val)
        if s  not in sample:
            #sarray+str(s)=[]
            if c>1:
                sample.append(s)
                print ("i am different")
#f.close()
print (sarray)
# Out:
# ['chr1:23343', '0.89', 'chr1:23359', '0.10', 'chr1:27843', '1.00', 'chr1:27876', '1.00', 'chr1:87409', '1.00', 'chr1:90946', '0.23', 'chr1:91009', '0.25', 'chr1:91013', '0.25', 'chr1:91035', '0.75', 'chr1:91054', '0.75', 'chr1:91063', '1.00', 'chr1:91190', '1.00', 'chr1:99389', '0.40', 'chr1:103210', '0.75', 'chr1:103233', '0.75', 'chr1:103250', '0.40', 'chr1:108517', '0.27', 'chr1:108540', '0.38', 'chr1:121344', '0.60']

# %%
f=open('all_candidates.txt','r')
c=0
sample=[]
sarray=[]
alldata=[]

for line in f:
    c=c+1
    #if c<20:
    #print (line)
    eachLine=line.strip().split('\t')
    #alldata.append(eachLine)

    #print (len(eachLine))
    #print(eachLine[1])
    s=eachLine[0]
    c1=eachLine[1]
    val=eachLine[3]
    #print (s)
    new=[]
    if c==1:
        sample.append(s)

        #s='HC1-11226-P-HC'
    #print(s,type(s))
    #if c==775531:
    #if c==20:
        #print (s)
    new.append(c1)
    new.append(s)
    new.append(val)
    if s  not in sample:
            #sarray+str(s)=[]
            if c>1:
                sample.append(s)
    alldata.append(new)
        
        
            
            
            
        
print (sample,len(alldata))
# Out:
# ['HC1-11225-P-HC', 'HC1-11226-P-HC', 'HC1-11227-P-HC', 'HC1-11228-P-HC', 'HC1-11229-P-HC', 'MS1-11001-P-NN', 'MS1-11002-P-NN', 'MS1-11006-P-NN', 'MS1-11008-P-NN', 'MS1-11015-P-NN'] 3770613

# %%
c=0
s1_2D=[]

#s1=['HC1-11225-P-HC', 'HC1-11225-P-HC', 'HC1-11225-P-HC', 'HC1-11225-P-HC']
for line in alldata:
    
    c=c+1
    #if c<20:
    c0=line[0]
    s0=line[1]
    v0=line[2]
    #print(c0,s0,v0)
    new=[]
    
    for l1 in alldata:
        
    
        #c=c+1
        #if c<20:
        c1=l1[0]
        s1=l1[1]
        v1=l1[2]
        #for s in sample:
            #s1_2D.append(sample)
            
        if c0==c1 and s0!=s1:
            new.append(c0)
            
            new.append(s0)
            
            new.append(v0)
            new.append(c1)
            new.append(s1)
            new.append(v1)
            s1_2D.append(new)

            #print ("found it",c0, s0,v0,c1,s1,v1)



#print (line[0])


    #new=[]
    #for l in alldata:
        #c1=l[0]
        #s1=l[1]
        #v1=l[2]
        #print(c1,s1,v1)
        #if c0==c1 and s0!=s1:
            #print ("found it")
        #new.append()
    #if c==1:
        #sample.append(s)

        #s='HC1-11226-P-HC'
    #print(s,type(s))
    #if c==775531:
    #if c==20:
        #print (s)
    
        
        
            
            
            
        
print (sample)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-169-4f59c6a45c67> in <module>
#      20         c1=l1[0]
#      21         s1=l1[1]
# ---> 22         v1=l1[2]
#      23         #for s in sample:
#      24             #s1_2D.append(sample)
#
# KeyboardInterrupt:

# %%
print(len(s1_2D))
# Out:
# 89703

# %%
import csv
c=0
stest_2D=[]

ss=['HC1-11225-P-HC', 'HC1-11226-P-HC', 'HC1-11227-P-HC']
for line in alldata:
    
    c=c+1
    #if c<20:
    c0=line[0]
    s0=line[1]
    v0=line[2]
    #print(c0,s0,v0)
    new=[]
    
    for l1 in alldata:
        
    
        #c=c+1
        #if c<20:
        c1=l1[0]
        s1=l1[1]
        v1=l1[2]
        #for s in sample:
            #s1_2D.append(sample)
            
        if c0==c1 and s0!=s1:
            new.append(c0)
            
            new.append(s0)
            
            new.append(v0)
            new.append(c1)
            new.append(s1)
            new.append(v1)
            #print (new)
            stest_2D.append(new)
            new=[]
            #print (stest_2D)

            #print (c0, s0,v0,c1,s1,v1)
            



#print (line[0])


    #new=[]
    #for l in alldata:
        #c1=l[0]
        #s1=l[1]
        #v1=l[2]
        #print(c1,s1,v1)
        #if c0==c1 and s0!=s1:
            #print ("found it")
        #new.append()
    #if c==1:
        #sample.append(s)

        #s='HC1-11226-P-HC'
    #print(s,type(s))
    #if c==775531:
    #if c==20:
        #print (s)
    
        
        
            
            
            
        
print (sample)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-183-386e605a6c17> in <module>
#      14     new=[]
#      15
# ---> 16     for l1 in alldata:
#      17
#      18
#
# KeyboardInterrupt:

# %%
print(len(stest_2D))
# Out:
# 6039

# %%
cc=0

     
for ii in stest_2D:
    cc=cc+1
    if cc<100:
        print (ii[0],ii[1],ii[2],ii[1],ii[4],ii[5])

        #print (ii)
        #for si in sample:
            #if si==ii[0]:
            
             
                #print (ii[0],ii[2],ii)

            #if ii[0]==ii[3]:

                #print(ii[0],"   ",end="")
                #print (ii[1],ii[4],ii[7],ii[10])
                #print ("          ",ii[2],"    ",ii[5],ii[8],ii[11])
# Out:
# chr1:23343 HC1-11225-P-HC 0.89 HC1-11225-P-HC HC1-11229-P-HC 0.78
# chr1:23343 HC1-11225-P-HC 0.89 HC1-11225-P-HC MS1-11002-P-NN 0.20
# chr1:23359 HC1-11225-P-HC 0.10 HC1-11225-P-HC HC1-11227-P-HC 1.00
# chr1:23359 HC1-11225-P-HC 0.10 HC1-11225-P-HC MS1-11001-P-NN 0.38
# chr1:23359 HC1-11225-P-HC 0.10 HC1-11225-P-HC MS1-11002-P-NN 0.29
# chr1:23359 HC1-11225-P-HC 0.10 HC1-11225-P-HC MS1-11006-P-NN 0.45
# chr1:23359 HC1-11225-P-HC 0.10 HC1-11225-P-HC MS1-11015-P-NN 0.36
# chr1:27876 HC1-11225-P-HC 1.00 HC1-11225-P-HC MS1-11001-P-NN 0.50
# chr1:27876 HC1-11225-P-HC 1.00 HC1-11225-P-HC MS1-11006-P-NN 0.25
# chr1:27876 HC1-11225-P-HC 1.00 HC1-11225-P-HC MS1-11015-P-NN 0.75
# chr1:90946 HC1-11225-P-HC 0.23 HC1-11225-P-HC MS1-11015-P-NN 0.41
# chr1:91013 HC1-11225-P-HC 0.25 HC1-11225-P-HC HC1-11227-P-HC 0.67
# chr1:91013 HC1-11225-P-HC 0.25 HC1-11225-P-HC MS1-11006-P-NN 0.50
# chr1:91013 HC1-11225-P-HC 0.25 HC1-11225-P-HC MS1-11015-P-NN 0.57
# ...

# %%
stest_2D1=[]
# Out:
# The original list is : ['gfg', 'is', 'best']
# The constructed Dictionary :  {'gfg': 'def_key_gfg', 'is': 'def_key_is', 'best': 'def_key_best'}

# %%
import pandas as pd 

df = pd.DataFrame(s1_2D ) 
print(df.head())
# Out:
#            0               1     2           3               4     5   \
# 0  chr1:23343  HC1-11225-P-HC  0.89  chr1:23343  HC1-11229-P-HC  0.78
# 1  chr1:23343  HC1-11225-P-HC  0.89  chr1:23343  HC1-11229-P-HC  0.78
# 2  chr1:23359  HC1-11225-P-HC  0.10  chr1:23359  HC1-11227-P-HC  1.00
# 3  chr1:23359  HC1-11225-P-HC  0.10  chr1:23359  HC1-11227-P-HC  1.00
# 4  chr1:23359  HC1-11225-P-HC  0.10  chr1:23359  HC1-11227-P-HC  1.00
#
#            6               7     8           9   ...    44    45    46    47  \
# 0  chr1:23343  HC1-11225-P-HC  0.89  chr1:23343  ...  None  None  None  None
# 1  chr1:23343  HC1-11225-P-HC  0.89  chr1:23343  ...  None  None  None  None
# 2  chr1:23359  HC1-11225-P-HC  0.10  chr1:23359  ...  None  None  None  None
# 3  chr1:23359  HC1-11225-P-HC  0.10  chr1:23359  ...  None  None  None  None
# 4  chr1:23359  HC1-11225-P-HC  0.10  chr1:23359  ...  None  None  None  None
#
#      48    49    50    51    52    53
# 0  None  None  None  None  None  None
# ...

# %%
import os, fnmatch
import csv
allcol=[]
listOfFiles = os.listdir('.')  
pattern = "*.csv"  
for entry in listOfFiles:  
    if fnmatch.fnmatch(entry, pattern):
        with open(entry, newline='') as csvfile:
            reader = csv.reader(csvfile)
            #print(reader)
            #allcol.append(("Nextfile"))
            scol=[]
            for line in reader:
                
                
                #allcol.append[line[0]]
                line0=line[0]
                #line0.replace(u'\ufeff', '')
                #line0=line0.encode('utf-8')  
                #print(line0)
                scol.append((line0))
            allcol.append(scol)
             
len(allcol)

# %%
print(len(allcol))
#print(scol)
#print(allcol)

# %%
comFile=open('sRNAs_list.csv','r')
a1=[]
cf=0
for line in comFile:
    cf+=1
    eachLine=line.rstrip().split(",")
    fcol=eachLine[0]
    a1.append(fcol)
    print("cf",cf, fcol)
print("cf",cf)

count=0
for i in a1: 
    count+=1
    #print (i)
print(count)

# %%
print(len(a1))

# %%
fmatch=[]
fcount=0
refC=0
valc=0
mcount=0
for i in a1: 
    refC+=1
    #print(mcount)
    if (mcount==9):
        valc+=1
        print(i)
    mcount=0

    for j in allcol :
        #mcount=0
        fcount+=1

        kc=0
        #print(mcount)
        for k in j:

            kc+=1


            #if kc<2:
                #print("kc",k)

            if k==i:
                #fmatch.append(i)


                        #print(" matched",k)
                #print(match)

                mcount+=1
                break
   
        
            
            

        

              
        
    
    

print("valcount", valc)
